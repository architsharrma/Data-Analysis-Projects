# %% [markdown]
# # HELLO EVERYONE, AGAIN WITH A NEW DATA ANALYSIS ON TELECOM DATASET.

# %% [markdown]
# ## THIS IS A PART-1 (DATA ANALYSIS) IN THESE WE WILL LEARN EVERYTHING FROM BASICS.

# %% [markdown]
# ## PART-2 WILL BE UPLOADED TOMORROW WHICH WILL BE BASED ON (DATA VISUALIZATION) WE WILL LEARN ALL IMPORTANT PLOTS USING MATPLOTLIB AND SEABORN.

# %% [markdown]
# ## Firstly import specific modules:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# READ THE CSV FILE:

# %%
telecom_data=pd.read_csv('BigML_Dataset_5f4ba58995a9302e500019e2.csv')

# %%
telecom_data.head(5)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
#LET'S CHECK HOW MANY ROWS AND COLUMNS OUR DATASET CONTAINS:
telecom_data.shape
# Out:
# (3333, 21)

# %%
# LET'S CHECK EACH COLUMN NAME:
telecom_data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
# LET'S CHECK THE DATATYPE OF EACH COLUMN:
telecom_data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %% [markdown]
# Now, we use info() method to gain some information related to our dataset:

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# AS THESE DATASET HAS NO NULL VALUES,YOU CAN SEE IN ABOVE OUTPUT.

# %% [markdown]
# We can change the column type with the astype method. Let’s apply this method to the Churn feature to convert it into int64:

# %%
telecom_data['churn']=telecom_data['churn'].astype('int64')

# %% [markdown]
# Let's see some statistical information related to our dataset:

# %%
telecom_data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# In order to see the statistical information of non-numerical datatypes we have to add include parameter.

# %% [markdown]
# Now we use value_counts method on categorical feature to see how many unique values our specific column contain:

# %%
telecom_data['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %% [markdown]
# You can see in above output that there is 2850 out of 3333 are loyal.

# %% [markdown]
# If you want to see above result in fractional form we had to add normalize parameter = True.

# %%
telecom_data['churn'].value_counts(normalize=True).round(2)
# Out:
# 0    0.86
# 1    0.14
# Name: churn, dtype: float64

# %% [markdown]
# ## SORTING OF OUR DATASET.

# %%
telecom_data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
telecom_data.sort_values(by=['total day calls'],ascending=False).head()
# Out:
#      state  account length  area code phone number international plan  \
# 1121    MI              91        415     390-7930                 no
# 468     AZ              86        415     392-2381                 no
# 1460    MT              80        415     361-8288                 no
# 2392    WY              90        510     400-8069                 no
# 1057    WV              86        415     332-2258                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 1121              no                      0              154.4
# 468              yes                     32               70.9
# 1460              no                      0              198.1
# 2392              no                      0              125.4
# 1057             yes                     38              123.0
#
#       total day calls  total day charge  ...  total eve calls  \
# 1121              165             26.25  ...              121
# ...

# %% [markdown]
# ### what is the proportion of churned users in our dataframe?

# %%
telecom_data['churn'].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# 14.5% is actually quite bad for a company; such a churn rate can make the company go bankrupt.

# %% [markdown]
# ### How much time (on average) do churned users spend on the phone during daytime?

# %%
telecom_data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
telecom_data[telecom_data['churn']==1]['total day minutes'].mean()
# Out:
# 206.91407867494814

# %% [markdown]
# ### What is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?

# %%
telecom_data[(telecom_data['churn']==0)  & (telecom_data['international plan'] =='no')]['total intl minutes'].max()
# Out:
# 18.9

# %% [markdown]
# ## INDEXING:

# %% [markdown]
# #### The loc method is used for indexing by name, while iloc() is used for indexing by number.

# %%
telecom_data.iloc[0:5,0:3]
# Out:
#   state  account length  area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %% [markdown]
# It shows that give us the values of first five rows for the first three column in above output.

# %%
telecom_data[:1] ##IF YOU NEED THE FIRST LINE
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
#
#    customer service calls  churn
# 0                       1      0
#
# [1 rows x 21 columns]

# %%
telecom_data[-1:] ##IF YOU WANT LAST LINE
# Out:
#      state  account length  area code phone number international plan  \
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3332              113             39.85  ...               82
#
#       total eve charge  total night minutes  total night calls  \
# 3332              22.6                241.4                 77
#
#       total night charge  total intl minutes  total intl calls  \
# 3332               10.86                13.7                 4
#
#       total intl charge  customer service calls  churn
# 3332                3.7                       0      0
#
# [1 rows x 21 columns]

# %% [markdown]
# ## APPLYING FUNCTIONS TO ROWS AND COLUMNS:

# %% [markdown]
# ### TO APPLY THE FUNCTIONS TO EACH COLUMN YOU NEED TO ADD APPLY() FUNCTION:
#     FOR EG: WE NEED TO APPLY MAX FUNCTION ON EACH COLUMN()

# %%
telecom_data.apply(np.max)
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes            350.8
# total day calls                165
# total day charge             59.64
# total eve minutes            363.7
# total eve calls                170
# total eve charge             30.91
# total night minutes            395
# total night calls              175
# total night charge           17.77
# total intl minutes              20
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                            1
# dtype: object

# %% [markdown]
# ### LAMBDA FUNCTION:They can have any number of arguments but only one expression

# %% [markdown]
# FOR EG: IF WE NEED TO SELECT ALL STATES STARTING WITH 'T' USING LAMBDA FUNCTION.

# %%
telecom_data[telecom_data['state'].apply(lambda state:state[0]=='T')]
# Out:
#      state  account length  area code phone number international plan  \
# 19      TX              73        415     373-2782                 no
# 69      TX             150        510     374-8042                 no
# 84      TX             106        510     395-3026                 no
# 121     TX              41        408     370-7550                 no
# 128     TX              92        408     409-5939                 no
# ...    ...             ...        ...          ...                ...
# 3168    TX             201        415     415-5476                 no
# 3210    TN              93        510     344-6847                yes
# 3289    TN              39        408     364-8731                 no
# 3295    TN             110        415     391-5516                 no
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# IN ABOVE OUTPUT 125 ROWS STARTS WITH STATE = 'T'.

# %% [markdown]
# ### LET'S CHECK TOTAL DAY CALLS WHICH ARE GREATER THAN 90.

# %%
telecom_data[telecom_data['total day calls'] > 90]
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# ...    ...             ...        ...          ...                ...
# 3326    OH              96        415     347-6812                 no
# 3327    SC              79        415     348-3830                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ### MAPPING:THIS METHOD CAN BE USE TO REPLACE A VALUE IN A COLUMN FOR EG:{OLD VALUE:NEW VALUE} AS AN ARGUMENT.

# %%
F={'no':False,'yes':True}
telecom_data['international plan']=telecom_data['international plan'].map(F)

# %%
telecom_data.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# Again do these for voice mail plan:

# %%
telecom_data['voice mail plan']=telecom_data['voice mail plan'].map(F)

# %%
telecom_data.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             True                     25              265.1              110
# 1             True                     26              161.6              123
# 2            False                      0              243.4              114
# 3            False                      0              299.4               71
# 4            False                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ## GROUPING METHOD:

# %%
columns_to_use=['total day minutes','total eve minutes','total night minutes']
telecom_data.groupby(['churn'])[columns_to_use].describe(percentiles=[])
# Out:
#       total day minutes                                            \
#                   count        mean        std  min    50%    max
# churn
# 0                2850.0  175.175754  50.181655  0.0  177.2  315.6
# 1                 483.0  206.914079  68.997792  0.0  217.6  350.8
#
#       total eve minutes                                             \
#                   count        mean        std   min    50%    max
# churn
# 0                2850.0  199.043298  50.292175   0.0  199.6  361.8
# 1                 483.0  212.410145  51.728910  70.9  211.3  363.7
#
#       total night minutes
#                     count        mean        std   min     50%    max
# churn
# 0                  2850.0  200.133193  51.105032  23.2  200.25  395.0
# 1                   483.0  205.231677  47.132825  47.4  204.80  354.9

# %% [markdown]
# ### CROSSTAB METHOD: THIS METHOD IS USE TO SEE HOW THE OBSERVATION IN OUR DATASET ARE DISTRIBUTED FOR TWO VARIABLES, FOR EG: LET'S TAKE CHURN AND INTERNATIONAL PLAN.

# %%
pd.crosstab(telecom_data['churn'],telecom_data['voice mail plan'],normalize=True).round(2)
# Out:
# voice mail plan  False  True
# churn
# 0                 0.60   0.25
# 1                 0.12   0.02

# %% [markdown]
# You can see in above output that majority of people i.e 60% people are loyal and do not use additional voice mail plan.

# %% [markdown]
# ## PIVOT TABLE:

# %% [markdown]
# IN PIVOT TABLE WE USE THREE PARAMETERS i.e 'VALUES','INDEX','AGGFUNC'.

# %%
telecom_data.pivot_table(['total day calls','total eve calls','total night calls'],['area code'],aggfunc='mean')
# Out:
#            total day calls  total eve calls  total night calls
# area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
telecom_data.pivot_table(['total day calls','total eve calls','total night calls'],['state'],aggfunc='max')
# Out:
#        total day calls  total eve calls  total night calls
# state
# AK                 129              147                137
# AL                 139              144                152
# AR                 145              159                144
# AZ                 163              146                138
# CA                 150              143                126
# CO                 145              137                142
# CT                 137              144                158
# DC                 147              134                133
# DE                 140              138                153
# FL                 143              168                146
# GA                 137              155                141
# HI                 147              157                138
# IA                 141              142                144
# ID                 151              143                164
# IL                 141              150                148
# ...

# %% [markdown]
# ## ADDING COLUMNS TO A DATAFRAME:

# %%
total_calls=telecom_data['total day calls']+telecom_data['total eve calls']+telecom_data['total night calls'] + telecom_data['total intl calls']
telecom_data.insert(loc=len(telecom_data.columns),column='Total calls',value=total_calls)
#we use loc function to define at which position we would like to insert our new column so here telecom_data.column means at the end.

# %%
telecom_data.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             True                     25              265.1              110
# 1             True                     26              161.6              123
# 2            False                      0              243.4              114
# 3            False                      0              299.4               71
# 4            False                      0              166.7              113
#
#    total day charge  ...  total night minutes  total night calls  \
# ...

# %%
telecom_data.sort_values(by=['Total calls'],ascending=False)  ##sorting values of total calls in the descending order.
# Out:
#      state  account length  area code phone number  international plan  \
# 3211    ID             103        415     391-7528               False
# 1739    NJ              80        415     330-4978               False
# 2263    UT              32        510     370-9563               False
# 2796    HI              24        415     329-8788               False
# 1370    PA              96        510     359-1441               False
# ...    ...             ...        ...          ...                 ...
# 2492    SC              73        415     344-9347               False
# 349     FL             100        510     420-7823               False
# 960     AR               5        415     380-2758               False
# 2274    GA              74        510     340-8245               False
# 1709    NV              96        408     375-6911               False
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ### DROP:

# %%
##IF YOU WANT TO USE DROP JUST SIMPLY TYPE:
telecom_data.drop(['Total calls'],axis=1,inplace=True)

# %%
telecom_data.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             True                     25              265.1              110
# 1             True                     26              161.6              123
# 2            False                      0              243.4              114
# 3            False                      0              299.4               71
# 4            False                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# You can see there is no column of total calls.

# %% [markdown]
# Now, to delete specific rows:

# %%
telecom_data.drop([1,2]) ##you can see 1,2 index values is deleted.
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657               False
# 3       OH              84        408     375-9999                True
# 4       OK              75        415     330-6626                True
# 5       AL             118        510     391-8027                True
# 6       MA             121        510     355-9993               False
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276               False
# 3329    WV              68        415     370-3271               False
# 3330    RI              28        510     328-8230               False
# 3331    CT             184        510     364-6381                True
# 3332    TN              74        415     400-4344               False
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# ## THIS IS THE ANALYSIS BASED ON PANDAS FROM BASICS I HOPE YOU ALL LIKE IT!!!
